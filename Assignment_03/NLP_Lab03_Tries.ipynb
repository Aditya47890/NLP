# %%
# ========================================
# NLP Assignment-2 : Prefix & Suffix Tries
# ========================================

# ---------- Trie Node ----------
class TrieNode:
    def __init__(self):
        self.children = {}
        self.is_end = False
        self.freq = 0  # frequency of words passing through this node


# ---------- Prefix Trie ----------
class PrefixTrie:
    def __init__(self):
        self.root = TrieNode()

    def insert(self, word: str):
        node = self.root
        for ch in word:  # left-to-right insertion
            if ch not in node.children:
                node.children[ch] = TrieNode()
            node = node.children[ch]
            node.freq += 1
        node.is_end = True

    def find_stem_suffix(self, word: str):
        node = self.root
        stem, suffix = "", ""
        branch_point = 0

        for i, ch in enumerate(word):
            if ch in node.children:
                node = node.children[ch]
                # branching → multiple children
                if len(node.children) > 1:
                    branch_point = i + 1
            else:
                break

        stem = word[:branch_point]
        suffix = word[branch_point:]
        return stem, suffix


# ---------- Suffix Trie ----------
class SuffixTrie:
    def __init__(self):
        self.root = TrieNode()

    def insert(self, word: str):
        node = self.root
        for ch in reversed(word):  # right-to-left insertion
            if ch not in node.children:
                node.children[ch] = TrieNode()
            node = node.children[ch]
            node.freq += 1
        node.is_end = True

    def find_stem_suffix(self, word: str):
        node = self.root
        stem, suffix = "", ""
        branch_point = 0

        rev_word = list(reversed(word))

        for i, ch in enumerate(rev_word):
            if ch in node.children:
                node = node.children[ch]
                if len(node.children) > 1:
                    branch_point = i + 1
            else:
                break

        # split original word using branch point
        stem = word[:len(word) - branch_point]
        suffix = word[len(word) - branch_point:]
        return stem, suffix


# ---------- Main Execution ----------
def main():
    # Load words dataset
    with open("brown_nouns.txt", "r") as f:
        words = [w.strip().lower() for w in f.readlines() if w.strip()]

    # Build Prefix Trie
    prefix_trie = PrefixTrie()
    for w in words:
        prefix_trie.insert(w)

    # Build Suffix Trie
    suffix_trie = SuffixTrie()
    for w in words:
        suffix_trie.insert(w)

    # Compare results
    print("=== Word Stemming Analysis ===\n")
    for w in words[:]:  # show first 30 words
        stem_p, suf_p = prefix_trie.find_stem_suffix(w)
        stem_s, suf_s = suffix_trie.find_stem_suffix(w)

        print(f"{w} (Prefix Trie) → {stem_p}+{suf_p}")
        print(f"{w} (Suffix Trie) → {stem_s}+{suf_s}\n")


if __name__ == "__main__":
    main()
# Out:
# Streaming output truncated to the last 5000 lines.
# couple (Suffix Trie) → cou+ple
#
# modifiers (Prefix Trie) → modifi+ers
# modifiers (Suffix Trie) → mod+ifiers
#
# headlinese (Prefix Trie) → headli+nese
# headlinese (Suffix Trie) → headli+nese
#
# journalism (Prefix Trie) → journalis+m
# journalism (Suffix Trie) → jou+rnalism
#
# variety (Prefix Trie) → variet+y
# variety (Suffix Trie) → va+riety
#
# ambiguities (Prefix Trie) → ambiguit+ies
# ambiguities (Suffix Trie) → ambig+uities
#
# matter (Prefix Trie) → matt+er
# matter (Suffix Trie) → m+atter
#
# newspaper (Prefix Trie) → newspaper+
# newspaper (Suffix Trie) → news+paper
#
# romance (Prefix Trie) → romance+
# romance (Suffix Trie) → ro+mance
#
# couple (Prefix Trie) → couple+
# couple (Suffix Trie) → cou+ple
#
# friendship (Prefix Trie) → friend+ship
# friendship (Suffix Trie) → frien+dship
#
# schooldays (Prefix Trie) → school+days
# schooldays (Suffix Trie) → school+days
#
# item (Prefix Trie) → item+
# item (Suffix Trie) → i+tem
#
# letters (Prefix Trie) → letter+s
# letters (Suffix Trie) → le+tters
#
# column (Prefix Trie) → column+
# column (Suffix Trie) → col+umn
#
# newspaper (Prefix Trie) → newspaper+
# newspaper (Suffix Trie) → news+paper
#
# subscription (Prefix Trie) → subscript+ion
# subscription (Suffix Trie) → sub+scription
#
# newspaper (Prefix Trie) → newspaper+
# newspaper (Suffix Trie) → news+paper
#
# husband (Prefix Trie) → husband+
# husband (Suffix Trie) → hus+band
#
# affair (Prefix Trie) → aff+air
# affair (Suffix Trie) → aff+air
#
# facilities (Prefix Trie) → facilit+ies
# facilities (Suffix Trie) → fac+ilities
#
# people (Prefix Trie) → peo+ple
# people (Suffix Trie) → peo+ple
#
# newspaper (Prefix Trie) → newspaper+
# newspaper (Suffix Trie) → news+paper
#
# habitat (Prefix Trie) → habita+t
# habitat (Suffix Trie) → habi+tat
#
# anatomical (Prefix Trie) → anatom+ical
# anatomical (Suffix Trie) → anato+mical
#
# slip (Prefix Trie) → slip+
# slip (Suffix Trie) → s+lip
#
# anatomy (Prefix Trie) → anatom+y
# anatomy (Suffix Trie) → ana+tomy
#
# samples (Prefix Trie) → sample+s
# samples (Suffix Trie) → s+amples
#
# invitation (Prefix Trie) → invit+ation
# invitation (Suffix Trie) → in+vitation
#
# reappearance (Prefix Trie) → reapp+earance
# reappearance (Suffix Trie) → re+appearance
#
# reason (Prefix Trie) → reason+
# reason (Suffix Trie) → +reason
#
# anatomical (Prefix Trie) → anatom+ical
# anatomical (Suffix Trie) → anato+mical
#
# journalese (Prefix Trie) → journal+ese
# journalese (Suffix Trie) → journal+ese
#
# news (Prefix Trie) → news+
# news (Suffix Trie) → n+ews
#
# items (Prefix Trie) → item+s
# items (Suffix Trie) → i+tems
#
# man (Prefix Trie) → man+
# man (Suffix Trie) → +man
#
# body (Prefix Trie) → body+
# body (Suffix Trie) → b+ody
#
# head (Prefix Trie) → head+
# head (Suffix Trie) → +head
#
# suburbs (Prefix Trie) → suburb+s
# suburbs (Suffix Trie) → sub+urbs
#
# church (Prefix Trie) → church+
# church (Suffix Trie) → ch+urch
#
# social (Prefix Trie) → socia+l
# social (Suffix Trie) → so+cial
#
# night (Prefix Trie) → night+
# night (Suffix Trie) → +night
#
# dog (Prefix Trie) → dog+
# dog (Suffix Trie) → +dog
#
# square (Prefix Trie) → squa+re
# square (Suffix Trie) → squ+are
#
# items (Prefix Trie) → item+s
# items (Suffix Trie) → i+tems
#
# journalist (Prefix Trie) → journalis+t
# journalist (Suffix Trie) → jour+nalist
#
# accident (Prefix Trie) → acc+ident
# accident (Suffix Trie) → ac+cident
#
# movie (Prefix Trie) → movi+e
# movie (Suffix Trie) → m+ovie
#
# star (Prefix Trie) → star+
# star (Suffix Trie) → s+tar
#
# area (Prefix Trie) → area+
# area (Suffix Trie) → a+rea
#
# meaning (Prefix Trie) → meaning+
# meaning (Suffix Trie) → m+eaning
#
# anatomical (Prefix Trie) → anatom+ical
# anatomical (Suffix Trie) → anato+mical
#
# vaudeville (Prefix Trie) → vau+deville
# vaudeville (Suffix Trie) → vaudev+ille
#
# device (Prefix Trie) → devi+ce
# device (Suffix Trie) → d+evice
#
# gags (Prefix Trie) → gag+s
# gags (Suffix Trie) → g+ags
#
# witness (Prefix Trie) → wit+ness
# witness (Suffix Trie) → w+itness
#
# court (Prefix Trie) → court+
# court (Suffix Trie) → co+urt
#
# rumpus (Prefix Trie) → rum+pus
# rumpus (Suffix Trie) → ru+mpus
#
# stomach (Prefix Trie) → stomac+h
# stomach (Suffix Trie) → stom+ach
#
# house (Prefix Trie) → house+
# house (Suffix Trie) → +house
#
# journalese (Prefix Trie) → journal+ese
# journalese (Suffix Trie) → journal+ese
#
# vaudeville (Prefix Trie) → vau+deville
# vaudeville (Suffix Trie) → vaudev+ille
#
# gags (Prefix Trie) → gag+s
# gags (Suffix Trie) → g+ags
#
# anatomical (Prefix Trie) → anatom+ical
# anatomical (Suffix Trie) → anato+mical
#
# literature (Prefix Trie) → litera+ture
# literature (Suffix Trie) → lit+erature
#
# girl (Prefix Trie) → girl+
# girl (Suffix Trie) → +girl
#
# secretary (Prefix Trie) → secretar+y
# secretary (Suffix Trie) → secre+tary
#
# doctor (Prefix Trie) → doctor+
# doctor (Suffix Trie) → d+octor
#
# day (Prefix Trie) → day+
# day (Suffix Trie) → +day
#
# work (Prefix Trie) → work+
# work (Suffix Trie) → +work
#
# entry (Prefix Trie) → entr+y
# entry (Suffix Trie) → +entry
#
# notes (Prefix Trie) → note+s
# notes (Suffix Trie) → +notes
#
# emergency (Prefix Trie) → emergenc+y
# emergency (Suffix Trie) → em+ergency
#
# case (Prefix Trie) → case+
# case (Suffix Trie) → +case
#
# region (Prefix Trie) → regi+on
# region (Suffix Trie) → r+egion
#
# moment (Prefix Trie) → moment+
# moment (Suffix Trie) → mo+ment
#
# thought (Prefix Trie) → thought+
# thought (Suffix Trie) → th+ought
#
# mind (Prefix Trie) → min+d
# mind (Suffix Trie) → m+ind
#
# interest (Prefix Trie) → intere+st
# interest (Suffix Trie) → inte+rest
#
# clarity (Prefix Trie) → clari+ty
# clarity (Suffix Trie) → c+larity
#
# record (Prefix Trie) → record+
# record (Suffix Trie) → re+cord
#
# woods (Prefix Trie) → woods+
# woods (Suffix Trie) → +woods
#
# misconstructions (Prefix Trie) → miscon+structions
# misconstructions (Suffix Trie) → misco+nstructions
#
# modifiers (Prefix Trie) → modifi+ers
# modifiers (Suffix Trie) → mod+ifiers
#
# anatomicals (Prefix Trie) → anatom+icals
# anatomicals (Suffix Trie) → anato+micals
#
# interpretations (Prefix Trie) → interpret+ations
# interpretations (Suffix Trie) → interpre+tations
#
# gourmet (Prefix Trie) → gour+met
# gourmet (Suffix Trie) → gour+met
#
# maid (Prefix Trie) → maid+
# maid (Suffix Trie) → m+aid
#
# points (Prefix Trie) → point+s
# points (Suffix Trie) → +points
#
# fish (Prefix Trie) → fish+
# fish (Suffix Trie) → +fish
#
# head (Prefix Trie) → head+
# head (Suffix Trie) → +head
#
# tail (Prefix Trie) → tail+
# tail (Suffix Trie) → +tail
#
# epicure (Prefix Trie) → epic+ure
# epicure (Suffix Trie) → epic+ure
#
# lemon (Prefix Trie) → lemon+
# lemon (Suffix Trie) → l+emon
#
# mouth (Prefix Trie) → mouth+
# mouth (Suffix Trie) → +mouth
#
# maid (Prefix Trie) → maid+
# maid (Suffix Trie) → m+aid
#
# lemon (Prefix Trie) → lemon+
# lemon (Suffix Trie) → l+emon
#
# mouth (Prefix Trie) → mouth+
# mouth (Suffix Trie) → +mouth
#
# gourmet (Prefix Trie) → gour+met
# gourmet (Suffix Trie) → gour+met
#
# way (Prefix Trie) → wa+y
# way (Suffix Trie) → +way
#
# dinners (Prefix Trie) → dinner+s
# dinners (Suffix Trie) → d+inners
#
# girl (Prefix Trie) → girl+
# girl (Suffix Trie) → +girl
#
# fish (Prefix Trie) → fish+
# fish (Suffix Trie) → +fish
#
# lemon (Prefix Trie) → lemon+
# lemon (Suffix Trie) → l+emon
#
# mouth (Prefix Trie) → mouth+
# mouth (Suffix Trie) → +mouth
#
# specimen (Prefix Trie) → specimen+
# specimen (Suffix Trie) → spec+imen
#
# woman (Prefix Trie) → wom+an
# woman (Suffix Trie) → wo+man
#
# department (Prefix Trie) → depart+ment
# department (Suffix Trie) → de+partment
#
# store (Prefix Trie) → store+
# store (Suffix Trie) → st+ore
#
# saleslady (Prefix Trie) → sales+lady
# saleslady (Suffix Trie) → sales+lady
#
# dress (Prefix Trie) → dress+
# dress (Suffix Trie) → +dress
#
# house (Prefix Trie) → house+
# house (Suffix Trie) → +house
#
# saleslady (Prefix Trie) → sales+lady
# saleslady (Suffix Trie) → sales+lady
#
# house (Prefix Trie) → house+
# house (Suffix Trie) → +house
#
# saleslady (Prefix Trie) → sales+lady
# saleslady (Suffix Trie) → sales+lady
#
# failure (Prefix Trie) → fai+lure
# failure (Suffix Trie) → fai+lure
#
# dress (Prefix Trie) → dress+
# dress (Suffix Trie) → +dress
#
# department (Prefix Trie) → depart+ment
# department (Suffix Trie) → de+partment
#
# shoe (Prefix Trie) → shoe+
# shoe (Suffix Trie) → sh+oe
#
# department (Prefix Trie) → depart+ment
# department (Suffix Trie) → de+partment
#
# customer (Prefix Trie) → custom+er
# customer (Suffix Trie) → cust+omer
#
# alligator (Prefix Trie) → alli+gator
# alligator (Suffix Trie) → all+igator
#
# shoes (Prefix Trie) → shoe+s
# shoes (Suffix Trie) → s+hoes
#
# size (Prefix Trie) → si+ze
# size (Suffix Trie) → s+ize
#
# alligator (Prefix Trie) → alli+gator
# alligator (Suffix Trie) → all+igator
#
# indefinite (Prefix Trie) → indefinit+e
# indefinite (Suffix Trie) → inde+finite
#
# class (Prefix Trie) → class+
# class (Suffix Trie) → c+lass
#
# comedy (Prefix Trie) → comed+y
# comedy (Suffix Trie) → co+medy
#
# species (Prefix Trie) → speci+es
# species (Suffix Trie) → sp+ecies
#
# statements (Prefix Trie) → state+ments
# statements (Suffix Trie) → sta+tements
#
# person (Prefix Trie) → person+
# person (Suffix Trie) → pe+rson
#
# place (Prefix Trie) → place+
# place (Suffix Trie) → +place
#
# time (Prefix Trie) → time+
# time (Suffix Trie) → +time
#
# thing (Prefix Trie) → thin+g
# thing (Suffix Trie) → +thing
#
# woman (Prefix Trie) → wom+an
# woman (Suffix Trie) → wo+man
#
# author (Prefix Trie) → author+
# author (Suffix Trie) → aut+hor
#
# tea (Prefix Trie) → tea+
# tea (Suffix Trie) → t+ea
#
# day (Prefix Trie) → day+
# day (Suffix Trie) → +day
#
# magazine (Prefix Trie) → mag+azine
# magazine (Suffix Trie) → mag+azine
#
# lack (Prefix Trie) → lac+k
# lack (Suffix Trie) → +lack
#
# details (Prefix Trie) → deta+ils
# details (Suffix Trie) → de+tails
#
# secretary (Prefix Trie) → secretar+y
# secretary (Suffix Trie) → secre+tary
#
# employer (Prefix Trie) → employe+r
# employer (Suffix Trie) → empl+oyer
#
# office (Prefix Trie) → office+
# office (Suffix Trie) → of+fice
#
# absence (Prefix Trie) → absen+ce
# absence (Suffix Trie) → ab+sence
#
# girl (Prefix Trie) → girl+
# girl (Suffix Trie) → +girl
#
# sir (Prefix Trie) → sir+
# sir (Suffix Trie) → s+ir
#
# mother (Prefix Trie) → mother+
# mother (Suffix Trie) → +mother
#
# daughter (Prefix Trie) → dau+ghter
# daughter (Suffix Trie) → d+aughter
#
# night (Prefix Trie) → night+
# night (Suffix Trie) → +night
#
# daughter (Prefix Trie) → dau+ghter
# daughter (Suffix Trie) → d+aughter
#
# dinner (Prefix Trie) → dinner+
# dinner (Suffix Trie) → d+inner
#
# couple (Prefix Trie) → couple+
# couple (Suffix Trie) → cou+ple
#
# places (Prefix Trie) → place+s
# places (Suffix Trie) → +places
#
# night (Prefix Trie) → night+
# night (Suffix Trie) → +night
#
# club (Prefix Trie) → club+
# club (Suffix Trie) → cl+ub
#
# name (Prefix Trie) → nam+e
# name (Suffix Trie) → +name
#
# parent (Prefix Trie) → parent+
# parent (Suffix Trie) → pa+rent
#
# course (Prefix Trie) → cour+se
# course (Suffix Trie) → +course
#
# indefinity (Prefix Trie) → indefinit+y
# indefinity (Suffix Trie) → inde+finity
#
# sermon (Prefix Trie) → ser+mon
# sermon (Suffix Trie) → ser+mon
#
# sins (Prefix Trie) → sin+s
# sins (Suffix Trie) → +sins
#
# measure (Prefix Trie) → measure+
# measure (Suffix Trie) → m+easure
#
# degree (Prefix Trie) → degr+ee
# degree (Suffix Trie) → de+gree
#
# extent (Prefix Trie) → exten+t
# extent (Suffix Trie) → ex+tent
#
# clergyman (Prefix Trie) → clergym+an
# clergyman (Suffix Trie) → clerg+yman
#
# dictum (Prefix Trie) → dict+um
# dictum (Suffix Trie) → dic+tum
#
# maxim (Prefix Trie) → maxim+
# maxim (Suffix Trie) → max+im
#
# reference (Prefix Trie) → referen+ce
# reference (Suffix Trie) → +reference
#
# allusion (Prefix Trie) → allusi+on
# allusion (Suffix Trie) → a+llusion
#
# person (Prefix Trie) → person+
# person (Suffix Trie) → pe+rson
#
# thing (Prefix Trie) → thin+g
# thing (Suffix Trie) → +thing
#
# news (Prefix Trie) → news+
# news (Suffix Trie) → n+ews
#
# item (Prefix Trie) → item+
# item (Suffix Trie) → i+tem
#
# launching (Prefix Trie) → launch+ing
# launching (Suffix Trie) → la+unching
#
# ship (Prefix Trie) → ship+
# ship (Suffix Trie) → +ship
#
# ceremony (Prefix Trie) → ceremon+y
# ceremony (Suffix Trie) → cer+emony
#
# movie (Prefix Trie) → movi+e
# movie (Suffix Trie) → m+ovie
#
# star (Prefix Trie) → star+
# star (Suffix Trie) → s+tar
#
# bottle (Prefix Trie) → bottle+
# bottle (Suffix Trie) → b+ottle
#
# champagne (Prefix Trie) → champ+agne
# champagne (Suffix Trie) → champag+ne
#
# stern (Prefix Trie) → stern+
# stern (Suffix Trie) → s+tern
#
# ways (Prefix Trie) → wa+ys
# ways (Suffix Trie) → +ways
#
# sea (Prefix Trie) → sea+
# sea (Suffix Trie) → s+ea
#
# order (Prefix Trie) → order+
# order (Suffix Trie) → +order
#
# sergeant (Prefix Trie) → ser+geant
# sergeant (Suffix Trie) → ser+geant
#
# army (Prefix Trie) → arm+y
# army (Suffix Trie) → a+rmy
#
# motor (Prefix Trie) → motor+
# motor (Suffix Trie) → m+otor
#
# pool (Prefix Trie) → poo+l
# pool (Suffix Trie) → p+ool
#
# trucks (Prefix Trie) → truck+s
# trucks (Suffix Trie) → tr+ucks
#
# gym (Prefix Trie) → gym+
# gym (Suffix Trie) → g+ym
#
# girls (Prefix Trie) → girl+s
# girls (Suffix Trie) → gi+rls
#
# dance (Prefix Trie) → dance+
# dance (Suffix Trie) → +dance
#
# bodies (Prefix Trie) → bodi+es
# bodies (Suffix Trie) → b+odies
#
# seats (Prefix Trie) → seat+s
# seats (Suffix Trie) → s+eats
#
# politician (Prefix Trie) → politic+ian
# politician (Suffix Trie) → poli+tician
#
# man (Prefix Trie) → man+
# man (Suffix Trie) → +man
#
# office (Prefix Trie) → office+
# office (Suffix Trie) → of+fice
#
# official (Prefix Trie) → official+
# official (Suffix Trie) → offi+cial
#
# chances (Prefix Trie) → chance+s
# chances (Suffix Trie) → ch+ances
#
# place (Prefix Trie) → place+
# place (Suffix Trie) → +place
#
# undertaker (Prefix Trie) → undertak+er
# undertaker (Suffix Trie) → unde+rtaker
#
# politician (Prefix Trie) → politic+ian
# politician (Suffix Trie) → poli+tician
#
# manager (Prefix Trie) → manage+r
# manager (Suffix Trie) → ma+nager
#
# movie (Prefix Trie) → movi+e
# movie (Suffix Trie) → m+ovie
#
# theater (Prefix Trie) → theater+
# theater (Suffix Trie) → th+eater
#
# telephone (Prefix Trie) → telephon+e
# telephone (Suffix Trie) → tele+phone
#
# call (Prefix Trie) → call+
# call (Suffix Trie) → c+all
#
# woman (Prefix Trie) → wom+an
# woman (Suffix Trie) → wo+man
#
# suit (Prefix Trie) → suit+
# suit (Suffix Trie) → +suit
#
# pause (Prefix Trie) → pau+se
# pause (Suffix Trie) → p+ause
#
# reflection (Prefix Trie) → reflect+ion
# reflection (Suffix Trie) → re+flection
#
# woman (Prefix Trie) → wom+an
# woman (Suffix Trie) → wo+man
#
# picture (Prefix Trie) → pictur+e
# picture (Suffix Trie) → pi+cture
#
# brand (Prefix Trie) → brand+
# brand (Suffix Trie) → b+rand
#
# reference (Prefix Trie) → referen+ce
# reference (Suffix Trie) → +reference
#
# use (Prefix Trie) → use+
# use (Suffix Trie) → +use
#
# verb (Prefix Trie) → verb+
# verb (Suffix Trie) → +verb
#
# question (Prefix Trie) → question+
# question (Suffix Trie) → qu+estion
#
# verbs (Prefix Trie) → verb+s
# verbs (Suffix Trie) → +verbs
#
# response (Prefix Trie) → respons+e
# response (Suffix Trie) → respo+nse
#
# night (Prefix Trie) → night+
# night (Suffix Trie) → +night
#
# romance (Prefix Trie) → romance+
# romance (Suffix Trie) → ro+mance
#
# time (Prefix Trie) → time+
# time (Suffix Trie) → +time
#
# thing (Prefix Trie) → thin+g
# thing (Suffix Trie) → +thing
#
# moment (Prefix Trie) → moment+
# moment (Suffix Trie) → mo+ment
#
# replies (Prefix Trie) → repli+es
# replies (Suffix Trie) → re+plies
#
# requests (Prefix Trie) → request+s
# requests (Suffix Trie) → r+equests
#
# character (Prefix Trie) → character+
# character (Suffix Trie) → chara+cter
#
# reference (Prefix Trie) → referen+ce
# reference (Suffix Trie) → +reference
#
# case (Prefix Trie) → case+
# case (Suffix Trie) → +case
#
# bearer (Prefix Trie) → bear+er
# bearer (Suffix Trie) → b+earer
#
# letter (Prefix Trie) → letter+
# letter (Suffix Trie) → le+tter
#
# years (Prefix Trie) → year+s
# years (Suffix Trie) → y+ears
#
# satisfaction (Prefix Trie) → sati+sfaction
# satisfaction (Suffix Trie) → satisf+action
#
# berth (Prefix Trie) → ber+th
# berth (Suffix Trie) → be+rth
#
# comedy (Prefix Trie) → comed+y
# comedy (Suffix Trie) → co+medy
#
# reference (Prefix Trie) → referen+ce
# reference (Suffix Trie) → +reference
#
# place (Prefix Trie) → place+
# place (Suffix Trie) → +place
#
# occurrence (Prefix Trie) → occu+rrence
# occurrence (Suffix Trie) → oc+currence
#
# ambiguity (Prefix Trie) → ambiguit+y
# ambiguity (Suffix Trie) → ambig+uity
#
# pronoun (Prefix Trie) → pronoun+
# pronoun (Suffix Trie) → prono+un
#
# reference (Prefix Trie) → referen+ce
# reference (Suffix Trie) → +reference
#
# friends (Prefix Trie) → friend+s
# friends (Suffix Trie) → fri+ends
#
# cold (Prefix Trie) → cold+
# cold (Suffix Trie) → c+old
#
# bottle (Prefix Trie) → bottle+
# bottle (Suffix Trie) → b+ottle
#
# whiskey (Prefix Trie) → whiske+y
# whiskey (Suffix Trie) → whis+key
#
# hours (Prefix Trie) → hou+rs
# hours (Suffix Trie) → h+ours
#
# speaker (Prefix Trie) → speak+er
# speaker (Suffix Trie) → sp+eaker
#
# whiskey (Prefix Trie) → whiske+y
# whiskey (Suffix Trie) → whis+key
#
# friend (Prefix Trie) → friend+
# friend (Suffix Trie) → fr+iend
#
# cold (Prefix Trie) → cold+
# cold (Suffix Trie) → c+old
#
# misnomer (Prefix Trie) → mis+nomer
# misnomer (Suffix Trie) → mis+nomer
#
# slips (Prefix Trie) → slip+s
# slips (Suffix Trie) → s+lips
#
# wit (Prefix Trie) → wit+
# wit (Suffix Trie) → w+it
#
# woman (Prefix Trie) → wom+an
# woman (Suffix Trie) → wo+man
#
# emergency (Prefix Trie) → emergenc+y
# emergency (Suffix Trie) → em+ergency
#
# call (Prefix Trie) → call+
# call (Suffix Trie) → c+all
#
# phone (Prefix Trie) → phone+
# phone (Suffix Trie) → +phone
#
# husband (Prefix Trie) → husband+
# husband (Suffix Trie) → hus+band
#
# pain (Prefix Trie) → pain+
# pain (Suffix Trie) → p+ain
#
# afternoon (Prefix Trie) → after+noon
# afternoon (Suffix Trie) → aftern+oon
#
# friend (Prefix Trie) → friend+
# friend (Suffix Trie) → fr+iend
#
# critic (Prefix Trie) → critic+
# critic (Suffix Trie) → cri+tic
#
# mother (Prefix Trie) → mother+
# mother (Suffix Trie) → +mother
#
# cottage (Prefix Trie) → cott+age
# cottage (Suffix Trie) → co+ttage
#
# hell (Prefix Trie) → hell+
# hell (Suffix Trie) → h+ell
#
# peacocks (Prefix Trie) → peac+ocks
# peacocks (Suffix Trie) → peac+ocks
#
# gentleman (Prefix Trie) → gentlem+an
# gentleman (Suffix Trie) → gent+leman
#
# man (Prefix Trie) → man+
# man (Suffix Trie) → +man
#
# state (Prefix Trie) → state+
# state (Suffix Trie) → +state
#
# literature (Prefix Trie) → litera+ture
# literature (Suffix Trie) → lit+erature
#
# human (Prefix Trie) → human+
# human (Suffix Trie) → hu+man
#
# stature (Prefix Trie) → statu+re
# stature (Suffix Trie) → st+ature
#
# hope (Prefix Trie) → hope+
# hope (Suffix Trie) → h+ope
#
# humor (Prefix Trie) → humo+r
# humor (Suffix Trie) → h+umor
#
# friend (Prefix Trie) → friend+
# friend (Suffix Trie) → fr+iend
#
# human (Prefix Trie) → human+
# human (Suffix Trie) → hu+man
#
# stature (Prefix Trie) → statu+re
# stature (Suffix Trie) → st+ature
#
# terms (Prefix Trie) → term+s
# terms (Suffix Trie) → t+erms
#
# speed (Prefix Trie) → speed+
# speed (Suffix Trie) → sp+eed
#
# momentum (Prefix Trie) → moment+um
# momentum (Suffix Trie) → mom+entum
#
# weightlessness (Prefix Trie) → weight+lessness
# weightlessness (Suffix Trie) → weigh+tlessness
#
# distance (Prefix Trie) → dista+nce
# distance (Suffix Trie) → d+istance
#
# earth (Prefix Trie) → earth+
# earth (Suffix Trie) → +earth
#
# matter (Prefix Trie) → matt+er
# matter (Suffix Trie) → m+atter
#
# development (Prefix Trie) → develop+ment
# development (Suffix Trie) → develo+pment
#
# human (Prefix Trie) → human+
# human (Suffix Trie) → hu+man
#
# mind (Prefix Trie) → min+d
# mind (Suffix Trie) → m+ind
#
# nation (Prefix Trie) → nation+
# nation (Suffix Trie) → +nation
#
# cult (Prefix Trie) → cult+
# cult (Suffix Trie) → c+ult
#
# personality (Prefix Trie) → personalit+y
# personality (Suffix Trie) → pers+onality
#
# careerism (Prefix Trie) → career+ism
# careerism (Suffix Trie) → care+erism
#
# letter (Prefix Trie) → letter+
# letter (Suffix Trie) → le+tter
#
# bee (Prefix Trie) → bee+
# bee (Suffix Trie) → +bee
#
# vacuum (Prefix Trie) → vacu+um
# vacuum (Suffix Trie) → vac+uum
#
# place (Prefix Trie) → place+
# place (Suffix Trie) → +place
#
# hive (Prefix Trie) → hi+ve
# hive (Suffix Trie) → +hive
#
# future (Prefix Trie) → fut+ure
# future (Suffix Trie) → fu+ture
#
# humor (Prefix Trie) → humo+r
# humor (Suffix Trie) → h+umor
#
# comedy (Prefix Trie) → comed+y
# comedy (Suffix Trie) → co+medy
#
# drink (Prefix Trie) → drink+
# drink (Suffix Trie) → d+rink
#
# hand (Prefix Trie) → hand+
# hand (Suffix Trie) → +hand
#
# interview (Prefix Trie) → interview+
# interview (Suffix Trie) → inter+view
#
# years (Prefix Trie) → year+s
# years (Suffix Trie) → y+ears
#
# humor (Prefix Trie) → humo+r
# humor (Suffix Trie) → h+umor
#
# comedy (Prefix Trie) → comed+y
# comedy (Suffix Trie) → co+medy
#
# years (Prefix Trie) → year+s
# years (Suffix Trie) → y+ears
#
# funeral (Prefix Trie) → fun+eral
# funeral (Suffix Trie) → fu+neral
#
# comedy (Prefix Trie) → comed+y
# comedy (Suffix Trie) → co+medy
#
# tension (Prefix Trie) → tens+ion
# tension (Suffix Trie) → +tension
#
# terror (Prefix Trie) → terro+r
# terror (Suffix Trie) → te+rror
#
# comedy (Prefix Trie) → comed+y
# comedy (Suffix Trie) → co+medy
#
# menace (Prefix Trie) → mena+ce
# menace (Suffix Trie) → me+nace
#
# horror (Prefix Trie) → hor+ror
# horror (Suffix Trie) → ho+rror
#
# jokes (Prefix Trie) → joke+s
# jokes (Suffix Trie) → j+okes
#
# magazines (Prefix Trie) → mag+azines
# magazines (Suffix Trie) → magaz+ines
#
# comedians (Prefix Trie) → comedi+ans
# comedians (Suffix Trie) → com+edians
#
# publications (Prefix Trie) → public+ations
# publications (Suffix Trie) → pub+lications
#
# loon (Prefix Trie) → loo+n
# loon (Suffix Trie) → +loon
#
# hare (Prefix Trie) → hare+
# hare (Suffix Trie) → h+are
#
# man (Prefix Trie) → man+
# man (Suffix Trie) → +man
#
# morning (Prefix Trie) → mor+ning
# morning (Suffix Trie) → mo+rning
#
# paraphrase (Prefix Trie) → paraph+rase
# paraphrase (Suffix Trie) → paraph+rase
#
# gulp (Prefix Trie) → gul+p
# gulp (Suffix Trie) → g+ulp
#
# drink (Prefix Trie) → drink+
# drink (Suffix Trie) → d+rink
#
# glass (Prefix Trie) → gla+ss
# glass (Suffix Trie) → g+lass
#
# paraphrase (Prefix Trie) → paraph+rase
# paraphrase (Suffix Trie) → paraph+rase
#
# time (Prefix Trie) → time+
# time (Suffix Trie) → +time
#
# walrus (Prefix Trie) → wal+rus
# walrus (Suffix Trie) → wal+rus
#
# things (Prefix Trie) → thin+gs
# things (Suffix Trie) → +things
#
# shots (Prefix Trie) → shot+s
# shots (Suffix Trie) → sh+ots
#
# shouts (Prefix Trie) → shout+s
# shouts (Suffix Trie) → sh+outs
#
# dooms (Prefix Trie) → doo+ms
# dooms (Suffix Trie) → d+ooms
#
# commoners (Prefix Trie) → common+ers
# commoners (Suffix Trie) → comm+oners
#
# kings (Prefix Trie) → king+s
# kings (Suffix Trie) → +kings
#
# drink (Prefix Trie) → drink+
# drink (Suffix Trie) → d+rink
#
# sake (Prefix Trie) → sa+ke
# sake (Suffix Trie) → s+ake
#
# moment (Prefix Trie) → moment+
# moment (Suffix Trie) → mo+ment
#
# day (Prefix Trie) → day+
# day (Suffix Trie) → +day
#
# anecdote (Prefix Trie) → ane+cdote
# anecdote (Suffix Trie) → anec+dote
#
# group (Prefix Trie) → group+
# group (Suffix Trie) → g+roup
#
# years (Prefix Trie) → year+s
# years (Suffix Trie) → y+ears
#
# railway (Prefix Trie) → rail+way
# railway (Suffix Trie) → rai+lway
#
# station (Prefix Trie) → station+
# station (Suffix Trie) → +station
#
# attendant (Prefix Trie) → attendan+t
# attendant (Suffix Trie) → at+tendant
#
# foreigners (Prefix Trie) → fore+igners
# foreigners (Suffix Trie) → fore+igners
#
# way (Prefix Trie) → wa+y
# way (Suffix Trie) → +way
#
# foreigners (Prefix Trie) → fore+igners
# foreigners (Suffix Trie) → fore+igners
#
# way (Prefix Trie) → wa+y
# way (Suffix Trie) → +way
#
# woman (Prefix Trie) → wom+an
# woman (Suffix Trie) → wo+man
#
# foreigners (Prefix Trie) → fore+igners
# foreigners (Suffix Trie) → fore+igners
#
# breath (Prefix Trie) → breath+
# breath (Suffix Trie) → b+reath
#
# swallow (Prefix Trie) → swa+llow
# swallow (Suffix Trie) → sw+allow
#
# drink (Prefix Trie) → drink+
# drink (Suffix Trie) → d+rink
#
# humor (Prefix Trie) → humo+r
# humor (Suffix Trie) → h+umor
#
# comedy (Prefix Trie) → comed+y
# comedy (Suffix Trie) → co+medy
#
# music (Prefix Trie) → music+
# music (Suffix Trie) → mu+sic
#
# comedy (Prefix Trie) → comed+y
# comedy (Suffix Trie) → co+medy
#
# matter (Prefix Trie) → matt+er
# matter (Suffix Trie) → m+atter
#
# music (Prefix Trie) → music+
# music (Suffix Trie) → mu+sic
#
# dialogue (Prefix Trie) → dial+ogue
# dialogue (Suffix Trie) → di+alogue
#
# books (Prefix Trie) → books+
# books (Suffix Trie) → +books
#
# nonism (Prefix Trie) → non+ism
# nonism (Suffix Trie) → n+onism
#
# day (Prefix Trie) → day+
# day (Suffix Trie) → +day
#
# story (Prefix Trie) → story+
# story (Suffix Trie) → s+tory
#
# demonstration (Prefix Trie) → demonstrati+on
# demonstration (Suffix Trie) → demo+nstration
#
# plan (Prefix Trie) → plan+
# plan (Suffix Trie) → p+lan
#
# nonsense (Prefix Trie) → nons+ense
# nonsense (Suffix Trie) → nons+ense
#
# evil (Prefix Trie) → evil+
# evil (Suffix Trie) → e+vil
#
# horror (Prefix Trie) → hor+ror
# horror (Suffix Trie) → ho+rror
#
# insanity (Prefix Trie) → ins+anity
# insanity (Suffix Trie) → ins+anity
#
# nonsense (Prefix Trie) → nons+ense
# nonsense (Suffix Trie) → nons+ense
#
# future (Prefix Trie) → fut+ure
# future (Suffix Trie) → fu+ture
#
# humor (Prefix Trie) → humo+r
# humor (Suffix Trie) → h+umor
#
# comedy (Prefix Trie) → comed+y
# comedy (Suffix Trie) → co+medy
#
# existence (Prefix Trie) → existen+ce
# existence (Suffix Trie) → ex+istence
#
# spirit (Prefix Trie) → spirit+
# spirit (Suffix Trie) → spi+rit
#
# heart (Prefix Trie) → heart+
# heart (Suffix Trie) → he+art
#
# era (Prefix Trie) → era+
# era (Suffix Trie) → +era
#
# science (Prefix Trie) → scien+ce
# science (Suffix Trie) → sc+ience
#
# heart (Prefix Trie) → heart+
# heart (Suffix Trie) → he+art
#
# verbs (Prefix Trie) → verb+s
# verbs (Suffix Trie) → +verbs
#
# year (Prefix Trie) → year+
# year (Suffix Trie) → y+ear
#
# television (Prefix Trie) → tele+vision
# television (Suffix Trie) → tel+evision
#
# program (Prefix Trie) → program+
# program (Suffix Trie) → pr+ogram
#
# task (Prefix Trie) → task+
# task (Suffix Trie) → t+ask
#
# playwright (Prefix Trie) → playwri+ght
# playwright (Suffix Trie) → playw+right
#
# light (Prefix Trie) → light+
# light (Suffix Trie) → +light
#
# corners (Prefix Trie) → corn+ers
# corners (Suffix Trie) → co+rners
#
# human (Prefix Trie) → human+
# human (Suffix Trie) → hu+man
#
# heart (Prefix Trie) → heart+
# heart (Suffix Trie) → he+art
#
# heart (Prefix Trie) → heart+
# heart (Suffix Trie) → he+art
#
# organ (Prefix Trie) → organ+
# organ (Suffix Trie) → or+gan
#
# symbol (Prefix Trie) → symbol+
# symbol (Suffix Trie) → symb+ol
#
# psyche (Prefix Trie) → psych+e
# psyche (Suffix Trie) → psy+che
#
# glands (Prefix Trie) → gland+s
# glands (Suffix Trie) → g+lands
#
# system (Prefix Trie) → system+
# system (Suffix Trie) → sys+tem
#
# heart (Prefix Trie) → heart+
# heart (Suffix Trie) → he+art
#
# rainbow (Prefix Trie) → rain+bow
# rainbow (Suffix Trie) → rain+bow
#
# sky (Prefix Trie) → sky+
# sky (Suffix Trie) → sk+y
#
# heart (Prefix Trie) → heart+
# heart (Suffix Trie) → he+art
#
# rapture (Prefix Trie) → rap+ture
# rapture (Suffix Trie) → r+apture
#
# daffodils (Prefix Trie) → da+ffodils
# daffodils (Suffix Trie) → daffod+ils
#
# heart (Prefix Trie) → heart+
# heart (Suffix Trie) → he+art
#
# years (Prefix Trie) → year+s
# years (Suffix Trie) → y+ears
#
# heart (Prefix Trie) → heart+
# heart (Suffix Trie) → he+art
#
# character (Prefix Trie) → character+
# character (Suffix Trie) → chara+cter
#
# stuff (Prefix Trie) → stu+ff
# stuff (Suffix Trie) → st+uff
#
# heart (Prefix Trie) → heart+
# heart (Suffix Trie) → he+art
#
# fate (Prefix Trie) → fat+e
# fate (Suffix Trie) → f+ate
#
# fate (Prefix Trie) → fat+e
# fate (Suffix Trie) → f+ate
#
# day (Prefix Trie) → day+
# day (Suffix Trie) → +day
#
# species (Prefix Trie) → speci+es
# species (Suffix Trie) → sp+ecies
#
# day (Prefix Trie) → day+
# day (Suffix Trie) → +day
#
# while (Prefix Trie) → whi+le
# while (Suffix Trie) → wh+ile
#
# silence (Prefix Trie) → sil+ence
# silence (Suffix Trie) → si+lence
#
# heart (Prefix Trie) → heart+
# heart (Suffix Trie) → he+art
#
# throat (Prefix Trie) → thro+at
# throat (Suffix Trie) → thr+oat
#
# mouth (Prefix Trie) → mouth+
# mouth (Suffix Trie) → +mouth
#
# stomach (Prefix Trie) → stomac+h
# stomach (Suffix Trie) → stom+ach
#
# shoes (Prefix Trie) → shoe+s
# shoes (Suffix Trie) → s+hoes
#
# breast (Prefix Trie) → breast+
# breast (Suffix Trie) → br+east
#
# sleeve (Prefix Trie) → slee+ve
# sleeve (Suffix Trie) → sle+eve
#
# silence (Prefix Trie) → sil+ence
# silence (Suffix Trie) → si+lence
#
# times (Prefix Trie) → time+s
# times (Suffix Trie) → t+imes
#
# host (Prefix Trie) → host+
# host (Suffix Trie) → h+ost
#
# visit (Prefix Trie) → visit+
# visit (Suffix Trie) → vi+sit
#
# turning (Prefix Trie) → turni+ng
# turning (Suffix Trie) → t+urning
#
# courts (Prefix Trie) → court+s
# courts (Suffix Trie) → co+urts
#
# law (Prefix Trie) → law+
# law (Suffix Trie) → +law
#
# theatres (Prefix Trie) → theatre+s
# theatres (Suffix Trie) → theat+res
#
# sex (Prefix Trie) → sex+
# sex (Suffix Trie) → s+ex
#
# dramas (Prefix Trie) → drama+s
# dramas (Suffix Trie) → d+ramas
#
# clergymen (Prefix Trie) → clergym+en
# clergymen (Suffix Trie) → clerg+ymen
#
# parishioners (Prefix Trie) → parish+ioners
# parishioners (Suffix Trie) → parish+ioners
#
# psychiatrists (Prefix Trie) → psychiatr+ists
# psychiatrists (Suffix Trie) → psychiat+rists
#
# patients (Prefix Trie) → patien+ts
# patients (Suffix Trie) → pat+ients
#
# law (Prefix Trie) → law+
# law (Suffix Trie) → +law
#
# courts (Prefix Trie) → court+s
# courts (Suffix Trie) → co+urts
#
# arenas (Prefix Trie) → are+nas
# arenas (Suffix Trie) → a+renas
#
# theatre (Prefix Trie) → theatre+
# theatre (Suffix Trie) → thea+tre
#
# scene (Prefix Trie) → scene+
# scene (Suffix Trie) → sc+ene
#
# years (Prefix Trie) → year+s
# years (Suffix Trie) → y+ears
#
# heyday (Prefix Trie) → he+yday
# heyday (Suffix Trie) → he+yday
#
# group (Prefix Trie) → group+
# group (Suffix Trie) → g+roup
#
# problems (Prefix Trie) → prob+lems
# problems (Suffix Trie) → probl+ems
#
# novel (Prefix Trie) → novel+
# novel (Suffix Trie) → n+ovel
#
# play (Prefix Trie) → play+
# play (Suffix Trie) → +play
#
# comedy (Prefix Trie) → comed+y
# comedy (Suffix Trie) → co+medy
#
# satire (Prefix Trie) → satir+e
# satire (Suffix Trie) → sa+tire
#
# brothel (Prefix Trie) → brothe+l
# brothel (Suffix Trie) → brot+hel
#
# dustbin (Prefix Trie) → dust+bin
# dustbin (Suffix Trie) → dust+bin
#
# kitchen (Prefix Trie) → kitchen+
# kitchen (Suffix Trie) → kitch+en
#
# sink (Prefix Trie) → sink+
# sink (Suffix Trie) → s+ink
#
# time (Prefix Trie) → time+
# time (Suffix Trie) → +time
#
# writers (Prefix Trie) → writ+ers
# writers (Suffix Trie) → +writers
#
# creatures (Prefix Trie) → creat+ures
# creatures (Suffix Trie) → cr+eatures
#
# woodwork (Prefix Trie) → woodw+ork
# woodwork (Suffix Trie) → woo+dwork
#
# rock (Prefix Trie) → rock+
# rock (Suffix Trie) → +rock
#
# meanings (Prefix Trie) → meaning+s
# meanings (Suffix Trie) → mea+nings
#
# word (Prefix Trie) → word+
# word (Suffix Trie) → +word
#
# sound (Prefix Trie) → sound+
# sound (Suffix Trie) → s+ound
#
# motor (Prefix Trie) → motor+
# motor (Suffix Trie) → m+otor
#
# friend (Prefix Trie) → friend+
# friend (Suffix Trie) → fr+iend
#
# wife (Prefix Trie) → wi+fe
# wife (Suffix Trie) → +wife
#
# police (Prefix Trie) → polic+e
# police (Suffix Trie) → po+lice
#
# husband (Prefix Trie) → husband+
# husband (Suffix Trie) → hus+band
#
# days (Prefix Trie) → day+s
# days (Suffix Trie) → +days
#
# nights (Prefix Trie) → night+s
# nights (Suffix Trie) → n+ights
#
# minute (Prefix Trie) → minut+e
# minute (Suffix Trie) → min+ute
#
# drink (Prefix Trie) → drink+
# drink (Suffix Trie) → d+rink
#
# glass (Prefix Trie) → gla+ss
# glass (Suffix Trie) → g+lass
#
# hell (Prefix Trie) → hell+
# hell (Suffix Trie) → h+ell
#
# line (Prefix Trie) → line+
# line (Suffix Trie) → +line
#
# word (Prefix Trie) → word+
# word (Suffix Trie) → +word
#
# change (Prefix Trie) → chang+e
# change (Suffix Trie) → +change
#
# country (Prefix Trie) → country+
# country (Suffix Trie) → cou+ntry
#
# house (Prefix Trie) → house+
# house (Suffix Trie) → +house
#
# wagon (Prefix Trie) → wag+on
# wagon (Suffix Trie) → w+agon
#
# institution (Prefix Trie) → institution+
# institution (Suffix Trie) → i+nstitution
#
# ambulance (Prefix Trie) → ambu+lance
# ambulance (Suffix Trie) → amb+ulance
#
# way (Prefix Trie) → wa+y
# way (Suffix Trie) → +way
#
# questionnaire (Prefix Trie) → question+naire
# questionnaire (Suffix Trie) → question+naire
#
# host (Prefix Trie) → host+
# host (Suffix Trie) → h+ost
#
# window (Prefix Trie) → window+
# window (Suffix Trie) → win+dow
#
# peacocks (Prefix Trie) → peac+ocks
# peacocks (Suffix Trie) → peac+ocks
#
# animals (Prefix Trie) → anima+ls
# animals (Suffix Trie) → an+imals
#
# human (Prefix Trie) → human+
# human (Suffix Trie) → hu+man
#
# species (Prefix Trie) → speci+es
# species (Suffix Trie) → sp+ecies
#
# woman (Prefix Trie) → wom+an
# woman (Suffix Trie) → wo+man
#
# sheep (Prefix Trie) → sheep+
# sheep (Suffix Trie) → sh+eep
#
# day (Prefix Trie) → day+
# day (Suffix Trie) → +day
#
# sun (Prefix Trie) → sun+
# sun (Suffix Trie) → s+un
#
# sheep (Prefix Trie) → sheep+
# sheep (Suffix Trie) → sh+eep
#
# world (Prefix Trie) → wor+ld
# world (Suffix Trie) → wor+ld
#
# end (Prefix Trie) → end+
# end (Suffix Trie) → +end
#
# sheep (Prefix Trie) → sheep+
# sheep (Suffix Trie) → sh+eep
#
# unison (Prefix Trie) → uni+son
# unison (Suffix Trie) → u+nison
#
# doubt (Prefix Trie) → doubt+
# doubt (Suffix Trie) → dou+bt
#
# sound (Prefix Trie) → sound+
# sound (Suffix Trie) → s+ound
#
# mockery (Prefix Trie) → moc+kery
# mockery (Suffix Trie) → mo+ckery
#
# sheep (Prefix Trie) → sheep+
# sheep (Suffix Trie) → sh+eep
#
# horse (Prefix Trie) → horse+
# horse (Suffix Trie) → +horse
#
# laugh (Prefix Trie) → laugh+
# laugh (Suffix Trie) → la+ugh
#
# drama (Prefix Trie) → drama+
# drama (Suffix Trie) → d+rama
#
# rhinoceros (Prefix Trie) → rhino+ceros
# rhinoceros (Suffix Trie) → rhinoc+eros
#
# effect (Prefix Trie) → effect+
# effect (Suffix Trie) → e+ffect
#
# audience (Prefix Trie) → audi+ence
# audience (Suffix Trie) → au+dience
#
# rhinos (Prefix Trie) → rhino+s
# rhinos (Suffix Trie) → rh+inos
#
# actor (Prefix Trie) → act+or
# actor (Suffix Trie) → +actor
#
# stage (Prefix Trie) → stage+
# stage (Suffix Trie) → +stage
#
# rhinoceros (Prefix Trie) → rhino+ceros
# rhinoceros (Suffix Trie) → rhinoc+eros
#
# rhinos (Prefix Trie) → rhino+s
# rhinos (Suffix Trie) → rh+inos
#
# language (Prefix Trie) → lan+guage
# language (Suffix Trie) → langu+age
#
# comedy (Prefix Trie) → comed+y
# comedy (Suffix Trie) → co+medy
#
# humor (Prefix Trie) → humo+r
# humor (Suffix Trie) → h+umor
#
# comedy (Prefix Trie) → comed+y
# comedy (Suffix Trie) → co+medy
#
# years (Prefix Trie) → year+s
# years (Suffix Trie) → y+ears
#
# things (Prefix Trie) → thin+gs
# things (Suffix Trie) → +things
#
# satire (Prefix Trie) → satir+e
# satire (Suffix Trie) → sa+tire
#
# irony (Prefix Trie) → iron+y
# irony (Suffix Trie) → i+rony
#
# humor (Prefix Trie) → humo+r
# humor (Suffix Trie) → h+umor
#
# comedy (Prefix Trie) → comed+y
# comedy (Suffix Trie) → co+medy
#
# human (Prefix Trie) → human+
# human (Suffix Trie) → hu+man
#
# being (Prefix Trie) → be+ing
# being (Suffix Trie) → b+eing
#
# spotlight (Prefix Trie) → spot+light
# spotlight (Suffix Trie) → spo+tlight
#
# world (Prefix Trie) → wor+ld
# world (Suffix Trie) → wor+ld
#
# cultist (Prefix Trie) → culti+st
# cultist (Suffix Trie) → cul+tist
#
# actor (Prefix Trie) → act+or
# actor (Suffix Trie) → +actor
#
# meeting (Prefix Trie) → meet+ing
# meeting (Suffix Trie) → m+eeting
#
# couple (Prefix Trie) → couple+
# couple (Suffix Trie) → cou+ple
#
# years (Prefix Trie) → year+s
# years (Suffix Trie) → y+ears
#
# joke (Prefix Trie) → joke+
# joke (Suffix Trie) → j+oke
#
# goat (Prefix Trie) → goa+t
# goat (Suffix Trie) → g+oat
#
# cabbage (Prefix Trie) → cab+bage
# cabbage (Suffix Trie) → cab+bage
#
# name (Prefix Trie) → nam+e
# name (Suffix Trie) → +name
#
# bit (Prefix Trie) → bit+
# bit (Suffix Trie) → +bit
#
# cat (Prefix Trie) → cat+
# cat (Suffix Trie) → +cat
#
# mice (Prefix Trie) → mic+e
# mice (Suffix Trie) → m+ice
#
# falcon (Prefix Trie) → fal+con
# falcon (Suffix Trie) → fal+con
#
# dove (Prefix Trie) → do+ve
# dove (Suffix Trie) → d+ove
#
# human (Prefix Trie) → human+
# human (Suffix Trie) → hu+man
#
# being (Prefix Trie) → be+ing
# being (Suffix Trie) → b+eing
#
# humanity (Prefix Trie) → humanit+y
# humanity (Suffix Trie) → hum+anity
#
# literature (Prefix Trie) → litera+ture
# literature (Suffix Trie) → lit+erature
#
# politics (Prefix Trie) → politic+s
# politics (Suffix Trie) → pol+itics
#
# fall (Prefix Trie) → fall+
# fall (Suffix Trie) → +fall
#
# peacocks (Prefix Trie) → peac+ocks
# peacocks (Suffix Trie) → peac+ocks
#
# world (Prefix Trie) → wor+ld
# world (Suffix Trie) → wor+ld
#
# age (Prefix Trie) → age+
# age (Suffix Trie) → +age
#
# science (Prefix Trie) → scien+ce
# science (Suffix Trie) → sc+ience
#
# man (Prefix Trie) → man+
# man (Suffix Trie) → +man
#
# sphere (Prefix Trie) → spher+e
# sphere (Suffix Trie) → +sphere
#
# sorrow (Prefix Trie) → sorr+ow
# sorrow (Suffix Trie) → s+orrow
#
# space (Prefix Trie) → space+
# space (Suffix Trie) → +space
#
# human (Prefix Trie) → human+
# human (Suffix Trie) → hu+man
#
# ego (Prefix Trie) → eg+o
# ego (Suffix Trie) → e+go
#
# science (Prefix Trie) → scien+ce
# science (Suffix Trie) → sc+ience
#
# fiction (Prefix Trie) → fi+ction
# fiction (Suffix Trie) → f+iction
#
# creatures (Prefix Trie) → creat+ures
# creatures (Suffix Trie) → cr+eatures
#
# planets (Prefix Trie) → planet+s
# planets (Suffix Trie) → pl+anets
#
# systems (Prefix Trie) → system+s
# systems (Suffix Trie) → sys+tems
#
# fruit (Prefix Trie) → fruit+
# fruit (Suffix Trie) → f+ruit
#
# bats (Prefix Trie) → bat+s
# bats (Suffix Trie) → b+ats
#
# human (Prefix Trie) → human+
# human (Suffix Trie) → hu+man
#
# being (Prefix Trie) → be+ing
# being (Suffix Trie) → b+eing
#
# planets (Prefix Trie) → planet+s
# planets (Suffix Trie) → pl+anets
#
# species (Prefix Trie) → speci+es
# species (Suffix Trie) → sp+ecies
#
# humor (Prefix Trie) → humo+r
# humor (Suffix Trie) → h+umor
#
# comedy (Prefix Trie) → comed+y
# comedy (Suffix Trie) → co+medy
#
# sense (Prefix Trie) → sens+e
# sense (Suffix Trie) → s+ense
#
# words (Prefix Trie) → word+s
# words (Suffix Trie) → +words
#
# day (Prefix Trie) → day+
# day (Suffix Trie) → +day
#
# tendency (Prefix Trie) → tendenc+y
# tendency (Suffix Trie) → t+endency
#
# species (Prefix Trie) → speci+es
# species (Suffix Trie) → sp+ecies
#
# uniqueness (Prefix Trie) → uni+queness
# uniqueness (Suffix Trie) → uniq+ueness
#
# religions (Prefix Trie) → religion+s
# religions (Suffix Trie) → reli+gions
#
# ideologies (Prefix Trie) → ideologi+es
# ideologies (Suffix Trie) → ide+ologies
#
# ideology (Prefix Trie) → ideolog+y
# ideology (Suffix Trie) → id+eology
#
# years (Prefix Trie) → year+s
# years (Suffix Trie) → y+ears
#
# writer (Prefix Trie) → writ+er
# writer (Suffix Trie) → +writer
#
# subject (Prefix Trie) → subject+
# subject (Suffix Trie) → su+bject
#
# example (Prefix Trie) → exam+ple
# example (Suffix Trie) → ex+ample
#
# spirit (Prefix Trie) → spirit+
# spirit (Suffix Trie) → spi+rit
#
# ideologist (Prefix Trie) → ideologi+st
# ideologist (Suffix Trie) → id+eologist
#
# world (Prefix Trie) → wor+ld
# world (Suffix Trie) → wor+ld
#
# jeopardy (Prefix Trie) → je+opardy
# jeopardy (Suffix Trie) → jeopa+rdy
#
# force (Prefix Trie) → force+
# force (Suffix Trie) → f+orce
#
# time (Prefix Trie) → time+
# time (Suffix Trie) → +time
#
# time (Prefix Trie) → time+
# time (Suffix Trie) → +time
#
# paranoiac (Prefix Trie) → para+noiac
# paranoiac (Suffix Trie) → parano+iac
#
# head (Prefix Trie) → head+
# head (Suffix Trie) → +head
#
# state (Prefix Trie) → state+
# state (Suffix Trie) → +state
#
# power (Prefix Trie) → power+
# power (Suffix Trie) → +power
#
# mad (Prefix Trie) → mad+
# mad (Suffix Trie) → m+ad
#
# satire (Prefix Trie) → satir+e
# satire (Suffix Trie) → sa+tire
#
# writer (Prefix Trie) → writ+er
# writer (Suffix Trie) → +writer
#
# satire (Prefix Trie) → satir+e
# satire (Suffix Trie) → sa+tire
#
# writers (Prefix Trie) → writ+ers
# writers (Suffix Trie) → +writers
#
# nooks (Prefix Trie) → noo+ks
# nooks (Suffix Trie) → n+ooks
#
# crannies (Prefix Trie) → cran+nies
# crannies (Suffix Trie) → cra+nnies
#
# ivory (Prefix Trie) → iv+ory
# ivory (Suffix Trie) → iv+ory
#
# towers (Prefix Trie) → towe+rs
# towers (Suffix Trie) → t+owers
#
# obscurity (Prefix Trie) → obscurit+y
# obscurity (Suffix Trie) → obs+curity
#
# complexity (Prefix Trie) → complexit+y
# complexity (Suffix Trie) → com+plexity
#
# poetry (Prefix Trie) → poet+ry
# poetry (Suffix Trie) → po+etry
#
# years (Prefix Trie) → year+s
# years (Suffix Trie) → y+ears
#
# rules (Prefix Trie) → rule+s
# rules (Suffix Trie) → r+ules
#
# reader (Prefix Trie) → read+er
# reader (Suffix Trie) → r+eader
#
# idea (Prefix Trie) → idea+
# idea (Suffix Trie) → id+ea
#
# story (Prefix Trie) → story+
# story (Suffix Trie) → s+tory
#
# day (Prefix Trie) → day+
# day (Suffix Trie) → +day
#
# children (Prefix Trie) → child+ren
# children (Suffix Trie) → +children
#
# horse (Prefix Trie) → horse+
# horse (Suffix Trie) → +horse
#
# back (Prefix Trie) → back+
# back (Suffix Trie) → +back
#
# mystery (Prefix Trie) → myster+y
# mystery (Suffix Trie) → my+stery
#
# policeman (Prefix Trie) → policem+an
# policeman (Suffix Trie) → polic+eman
#
# voice (Prefix Trie) → voi+ce
# voice (Suffix Trie) → v+oice
#
# time (Prefix Trie) → time+
# time (Suffix Trie) → +time
#
# eyes (Prefix Trie) → eye+s
# eyes (Suffix Trie) → e+yes
#
# second (Prefix Trie) → second+
# second (Suffix Trie) → sec+ond
#
# tone (Prefix Trie) → tone+
# tone (Suffix Trie) → +tone
#
# hurry (Prefix Trie) → hurr+y
# hurry (Suffix Trie) → h+urry
#
# children (Prefix Trie) → child+ren
# children (Suffix Trie) → +children
#
# policeman (Prefix Trie) → policem+an
# policeman (Suffix Trie) → polic+eman
#
# look (Prefix Trie) → look+
# look (Suffix Trie) → l+ook
#
# face (Prefix Trie) → face+
# face (Suffix Trie) → +face
#
# kind (Prefix Trie) → kind+
# kind (Suffix Trie) → k+ind
#
# lady (Prefix Trie) → lad+y
# lady (Suffix Trie) → +lady
#
# kids (Prefix Trie) → kid+s
# kids (Suffix Trie) → k+ids
#
# park (Prefix Trie) → park+
# park (Suffix Trie) → p+ark
#
# city (Prefix Trie) → cit+y
# city (Suffix Trie) → +city
#
# ordinance (Prefix Trie) → ordina+nce
# ordinance (Suffix Trie) → ord+inance
#
# statues (Prefix Trie) → statue+s
# statues (Suffix Trie) → sta+tues
#
# head (Prefix Trie) → head+
# head (Suffix Trie) → +head
#
# sir (Prefix Trie) → sir+
# sir (Suffix Trie) → s+ir
#
# policeman (Prefix Trie) → policem+an
# policeman (Suffix Trie) → polic+eman
#
# day (Prefix Trie) → day+
# day (Suffix Trie) → +day
#
# things (Prefix Trie) → thin+gs
# things (Suffix Trie) → +things
#
# way (Prefix Trie) → wa+y
# way (Suffix Trie) → +way
#
# fun (Prefix Trie) → fun+
# fun (Suffix Trie) → f+un
#
# area (Prefix Trie) → area+
# area (Suffix Trie) → a+rea
#
# mother (Prefix Trie) → mother+
# mother (Suffix Trie) → +mother
#
# tumbles (Prefix Trie) → tumble+s
# tumbles (Suffix Trie) → tu+mbles
#
# matters (Prefix Trie) → matt+ers
# matters (Suffix Trie) → m+atters
#
# information (Prefix Trie) → informa+tion
# information (Suffix Trie) → i+nformation
#
# step (Prefix Trie) → step+
# step (Suffix Trie) → +step
#
# developments (Prefix Trie) → develop+ments
# developments (Suffix Trie) → develo+pments
#
# principles (Prefix Trie) → princip+les
# principles (Suffix Trie) → prin+ciples
#
# policeman (Prefix Trie) → policem+an
# policeman (Suffix Trie) → polic+eman
#
# course (Prefix Trie) → cour+se
# course (Suffix Trie) → +course
#
# grownups (Prefix Trie) → grow+nups
# grownups (Suffix Trie) → grow+nups
#
# fun (Prefix Trie) → fun+
# fun (Suffix Trie) → f+un
#
# lawn (Prefix Trie) → law+n
# lawn (Suffix Trie) → l+awn
#
# children (Prefix Trie) → child+ren
# children (Suffix Trie) → +children
#
# reflexes (Prefix Trie) → refle+xes
# reflexes (Suffix Trie) → ref+lexes
#
# replies (Prefix Trie) → repli+es
# replies (Suffix Trie) → re+plies
#
# unpredictability (Prefix Trie) → unp+redictability
# unpredictability (Suffix Trie) → unpredi+ctability
#
# dialogue (Prefix Trie) → dial+ogue
# dialogue (Suffix Trie) → di+alogue
#
# movie (Prefix Trie) → movi+e
# movie (Suffix Trie) → m+ovie
#
# lawn (Prefix Trie) → law+n
# lawn (Suffix Trie) → l+awn
#
# time (Prefix Trie) → time+
# time (Suffix Trie) → +time
#
# somersaults (Prefix Trie) → some+rsaults
# somersaults (Suffix Trie) → somer+saults
#
# surprise (Prefix Trie) → surp+rise
# surprise (Suffix Trie) → su+rprise
#
# insinuations (Prefix Trie) → insi+nuations
# insinuations (Suffix Trie) → insin+uations
#
# statement (Prefix Trie) → state+ment
# statement (Suffix Trie) → +statement
#
# oatmeal (Prefix Trie) → oat+meal
# oatmeal (Suffix Trie) → oat+meal
#
# children (Prefix Trie) → child+ren
# children (Suffix Trie) → +children
#
# bit (Prefix Trie) → bit+
# bit (Suffix Trie) → +bit
#
# things (Prefix Trie) → thin+gs
# things (Suffix Trie) → +things
#
# questions (Prefix Trie) → question+s
# questions (Suffix Trie) → qu+estions
#
# questions (Prefix Trie) → question+s
# questions (Suffix Trie) → qu+estions
#
# ones (Prefix Trie) → one+s
# ones (Suffix Trie) → +ones
#
# grownups (Prefix Trie) → grow+nups
# grownups (Suffix Trie) → grow+nups
#
# formation (Prefix Trie) → formati+on
# formation (Suffix Trie) → +formation
#
# root (Prefix Trie) → roo+t
# root (Suffix Trie) → r+oot
#
# oak (Prefix Trie) → oa+k
# oak (Suffix Trie) → +oak
#
# sort (Prefix Trie) → sort+
# sort (Suffix Trie) → s+ort
#
# root (Prefix Trie) → roo+t
# root (Suffix Trie) → r+oot
#
# bottoms (Prefix Trie) → bott+oms
# bottoms (Suffix Trie) → bot+toms
#
# horse (Prefix Trie) → horse+
# horse (Suffix Trie) → +horse
#
# children (Prefix Trie) → child+ren
# children (Suffix Trie) → +children
#
# bottoms (Prefix Trie) → bott+oms
# bottoms (Suffix Trie) → bot+toms
#
# curiosity (Prefix Trie) → cur+iosity
# curiosity (Suffix Trie) → cur+iosity
#
# bounds (Prefix Trie) → bound+s
# bounds (Suffix Trie) → b+ounds
#
# way (Prefix Trie) → wa+y
# way (Suffix Trie) → +way
#
# way (Prefix Trie) → wa+y
# way (Suffix Trie) → +way
#
# head (Prefix Trie) → head+
# head (Suffix Trie) → +head
#
# part (Prefix Trie) → part+
# part (Suffix Trie) → +part
#
# picture (Prefix Trie) → pictur+e
# picture (Suffix Trie) → pi+cture
#
# frame (Prefix Trie) → frame+
# frame (Suffix Trie) → fr+ame
#
# horse (Prefix Trie) → horse+
# horse (Suffix Trie) → +horse
#
# sort (Prefix Trie) → sort+
# sort (Suffix Trie) → s+ort
#
# kind (Prefix Trie) → kind+
# kind (Suffix Trie) → k+ind
#
# position (Prefix Trie) → positi+on
# position (Suffix Trie) → +position
#
# belly (Prefix Trie) → bell+y
# belly (Suffix Trie) → +belly
#
# feet (Prefix Trie) → fee+t
# feet (Suffix Trie) → f+eet
#
# smile (Prefix Trie) → smi+le
# smile (Suffix Trie) → s+mile
#
# lots (Prefix Trie) → lot+s
# lots (Suffix Trie) → +lots
#
# teeth (Prefix Trie) → teet+h
# teeth (Suffix Trie) → te+eth
#
# kisses (Prefix Trie) → kiss+es
# kisses (Suffix Trie) → k+isses
#
# time (Prefix Trie) → time+
# time (Suffix Trie) → +time
#
# lips (Prefix Trie) → li+ps
# lips (Suffix Trie) → +lips
#
# eyelids (Prefix Trie) → eyel+ids
# eyelids (Suffix Trie) → eye+lids
#
# time (Prefix Trie) → time+
# time (Suffix Trie) → +time
#
# time (Prefix Trie) → time+
# time (Suffix Trie) → +time
#
# bit (Prefix Trie) → bit+
# bit (Suffix Trie) → +bit
#
# horse (Prefix Trie) → horse+
# horse (Suffix Trie) → +horse
#
# time (Prefix Trie) → time+
# time (Suffix Trie) → +time
#
# horse (Prefix Trie) → horse+
# horse (Suffix Trie) → +horse
#
# circle (Prefix Trie) → circ+le
# circle (Suffix Trie) → cir+cle
#
# legs (Prefix Trie) → leg+s
# legs (Suffix Trie) → l+egs
#
# shaking (Prefix Trie) → shak+ing
# shaking (Suffix Trie) → sh+aking
#
# body (Prefix Trie) → body+
# body (Suffix Trie) → b+ody
#
# hips (Prefix Trie) → hip+s
# hips (Suffix Trie) → +hips
#
# shoulders (Prefix Trie) → shou+lders
# shoulders (Suffix Trie) → sh+oulders
#
# horse (Prefix Trie) → horse+
# horse (Suffix Trie) → +horse
#
# laughter (Prefix Trie) → laugh+ter
# laughter (Suffix Trie) → l+aughter
#
# horse (Prefix Trie) → horse+
# horse (Suffix Trie) → +horse
#
# wife (Prefix Trie) → wi+fe
# wife (Suffix Trie) → +wife
#
# father (Prefix Trie) → fath+er
# father (Suffix Trie) → f+ather
#
# business (Prefix Trie) → business+
# business (Suffix Trie) → b+usiness
#
# trips (Prefix Trie) → trip+s
# trips (Suffix Trie) → t+rips
#
# mother (Prefix Trie) → mother+
# mother (Suffix Trie) → +mother
#
# forehead (Prefix Trie) → fore+head
# forehead (Suffix Trie) → for+ehead
#
# lips (Prefix Trie) → li+ps
# lips (Suffix Trie) → +lips
#
# martinis (Prefix Trie) → martin+is
# martinis (Suffix Trie) → mart+inis
#
# icebox (Prefix Trie) → ic+ebox
# icebox (Suffix Trie) → ice+box
#
# man (Prefix Trie) → man+
# man (Suffix Trie) → +man
#
# feet (Prefix Trie) → fee+t
# feet (Suffix Trie) → f+eet
#
# horse (Prefix Trie) → horse+
# horse (Suffix Trie) → +horse
#
# circles (Prefix Trie) → circ+les
# circles (Suffix Trie) → cir+cles
#
# legs (Prefix Trie) → leg+s
# legs (Suffix Trie) → l+egs
#
# head (Prefix Trie) → head+
# head (Suffix Trie) → +head
#
# somersaults (Prefix Trie) → some+rsaults
# somersaults (Suffix Trie) → somer+saults
#
# sister (Prefix Trie) → si+ster
# sister (Suffix Trie) → s+ister
#
# lot (Prefix Trie) → lot+
# lot (Suffix Trie) → +lot
#
# bit (Prefix Trie) → bit+
# bit (Suffix Trie) → +bit
#
# lot (Prefix Trie) → lot+
# lot (Suffix Trie) → +lot
#
# lips (Prefix Trie) → li+ps
# lips (Suffix Trie) → +lips
#
# allowance (Prefix Trie) → allo+wance
# allowance (Suffix Trie) → allow+ance
#
# lips (Prefix Trie) → li+ps
# lips (Suffix Trie) → +lips
#
# deal (Prefix Trie) → deal+
# deal (Suffix Trie) → +deal
#
# tone (Prefix Trie) → tone+
# tone (Suffix Trie) → +tone
#
# mother (Prefix Trie) → mother+
# mother (Suffix Trie) → +mother
#
# voice (Prefix Trie) → voi+ce
# voice (Suffix Trie) → v+oice
#
# mother (Prefix Trie) → mother+
# mother (Suffix Trie) → +mother
#
# way (Prefix Trie) → wa+y
# way (Suffix Trie) → +way
#
# ma'am (Prefix Trie) → ma+'am
# ma'am (Suffix Trie) → ma'+am
#
# children (Prefix Trie) → child+ren
# children (Suffix Trie) → +children
#
# children (Prefix Trie) → child+ren
# children (Suffix Trie) → +children
#
# sweaters (Prefix Trie) → sweat+ers
# sweaters (Suffix Trie) → sw+eaters
#
# kitchen (Prefix Trie) → kitchen+
# kitchen (Suffix Trie) → kitch+en
#
# door (Prefix Trie) → door+
# door (Suffix Trie) → d+oor
#
# girl (Prefix Trie) → girl+
# ...
#
# base (Prefix Trie) → base+
# base (Suffix Trie) → b+ase
#
# belief (Prefix Trie) → belie+f
# belief (Suffix Trie) → b+elief
#
# gods (Prefix Trie) → god+s
# gods (Suffix Trie) → g+ods
#
# rest (Prefix Trie) → rest+
# rest (Suffix Trie) → +rest
#
# folk (Prefix Trie) → folk+
# folk (Suffix Trie) → +folk
#
# retribution (Prefix Trie) → retri+bution
# retribution (Suffix Trie) → re+tribution
#
# jokers (Prefix Trie) → joke+rs
# jokers (Suffix Trie) → j+okers
#
# years (Prefix Trie) → year+s
# years (Suffix Trie) → y+ears
#
# couple (Prefix Trie) → couple+
# couple (Suffix Trie) → cou+ple
#
# hoods (Prefix Trie) → hood+s
# hoods (Suffix Trie) → +hoods
#
# head (Prefix Trie) → head+
# head (Suffix Trie) → +head
#
# week (Prefix Trie) → week+
# week (Suffix Trie) → w+eek
#
# symptoms (Prefix Trie) → symp+toms
# symptoms (Suffix Trie) → symp+toms
#
# leprosy (Prefix Trie) → lepr+osy
# leprosy (Suffix Trie) → lepro+sy
#
# chaulmoogra (Prefix Trie) → chau+lmoogra
# chaulmoogra (Suffix Trie) → chaulmoo+gra
#
# oil (Prefix Trie) → oil+
# oil (Suffix Trie) → +oil
#
# torment (Prefix Trie) → tor+ment
# torment (Suffix Trie) → to+rment
#
# fantods (Prefix Trie) → fant+ods
# fantods (Suffix Trie) → fant+ods
#
# desecration (Prefix Trie) → dese+cration
# desecration (Suffix Trie) → de+secration
#
# interne (Prefix Trie) → intern+e
# interne (Suffix Trie) → inte+rne
#
# dozen (Prefix Trie) → do+zen
# dozen (Suffix Trie) → do+zen
#
# instances (Prefix Trie) → instanc+es
# instances (Suffix Trie) → in+stances
#
# case (Prefix Trie) → case+
# case (Suffix Trie) → +case
#
# experience (Prefix Trie) → experi+ence
# experience (Suffix Trie) → exper+ience
#
# moment (Prefix Trie) → moment+
# moment (Suffix Trie) → mo+ment
#
# catalogue (Prefix Trie) → catalog+ue
# catalogue (Suffix Trie) → cat+alogue
#
# pair (Prefix Trie) → pai+r
# pair (Suffix Trie) → +pair
#
# ivory (Prefix Trie) → iv+ory
# ivory (Suffix Trie) → iv+ory
#
# carvings (Prefix Trie) → carv+ings
# carvings (Suffix Trie) → ca+rvings
#
# juju (Prefix Trie) → ju+ju
# juju (Suffix Trie) → juj+u
#
# livers (Prefix Trie) → liver+s
# livers (Suffix Trie) → l+ivers
#
# lead (Prefix Trie) → lead+
# lead (Suffix Trie) → l+ead
#
# dealer (Prefix Trie) → deal+er
# dealer (Suffix Trie) → d+ealer
#
# ivory (Prefix Trie) → iv+ory
# ivory (Suffix Trie) → iv+ory
#
# female (Prefix Trie) → fem+ale
# female (Suffix Trie) → fe+male
#
# figure (Prefix Trie) → figur+e
# figure (Suffix Trie) → fig+ure
#
# doctor (Prefix Trie) → doctor+
# doctor (Suffix Trie) → d+octor
#
# lady (Prefix Trie) → lad+y
# lady (Suffix Trie) → +lady
#
# provenance (Prefix Trie) → prove+nance
# provenance (Suffix Trie) → prov+enance
#
# friend (Prefix Trie) → friend+
# friend (Suffix Trie) → fr+iend
#
# curio (Prefix Trie) → cur+io
# curio (Suffix Trie) → cu+rio
#
# cabinet (Prefix Trie) → cabinet+
# cabinet (Suffix Trie) → cab+inet
#
# inspection (Prefix Trie) → inspect+ion
# inspection (Suffix Trie) → in+spection
#
# hammer (Prefix Trie) → hamm+er
# hammer (Suffix Trie) → h+ammer
#
# quantity (Prefix Trie) → quantit+y
# quantity (Suffix Trie) → qua+ntity
#
# applejack (Prefix Trie) → apple+jack
# applejack (Suffix Trie) → apple+jack
#
# brass (Prefix Trie) → bras+s
# brass (Suffix Trie) → b+rass
#
# deities (Prefix Trie) → deit+ies
# deities (Suffix Trie) → de+ities
#
# cup (Prefix Trie) → cup+
# cup (Suffix Trie) → c+up
#
# tea (Prefix Trie) → tea+
# tea (Suffix Trie) → t+ea
#
# state (Prefix Trie) → state+
# state (Suffix Trie) → +state
#
# subcontinent (Prefix Trie) → subcon+tinent
# subcontinent (Suffix Trie) → subconti+nent
#
# goddess (Prefix Trie) → god+dess
# goddess (Suffix Trie) → god+dess
#
# death (Prefix Trie) → death+
# death (Suffix Trie) → d+eath
#
# sculpture (Prefix Trie) → sculpt+ure
# sculpture (Suffix Trie) → scul+pture
#
# men (Prefix Trie) → men+
# men (Suffix Trie) → +men
#
# heads (Prefix Trie) → heads+
# heads (Suffix Trie) → +heads
#
# bodies (Prefix Trie) → bodi+es
# bodies (Suffix Trie) → b+odies
#
# fish (Prefix Trie) → fish+
# fish (Suffix Trie) → +fish
#
# attention (Prefix Trie) → atten+tion
# attention (Suffix Trie) → at+tention
#
# amulet (Prefix Trie) → amu+let
# amulet (Suffix Trie) → amu+let
#
# housebreakers (Prefix Trie) → housebreak+ers
# housebreakers (Suffix Trie) → hous+ebreakers
#
# rajah (Prefix Trie) → ra+jah
# rajah (Suffix Trie) → raj+ah
#
# base (Prefix Trie) → base+
# base (Suffix Trie) → b+ase
#
# charm (Prefix Trie) → char+m
# charm (Suffix Trie) → ch+arm
#
# dialect (Prefix Trie) → dialect+
# dialect (Suffix Trie) → dia+lect
#
# rooftree (Prefix Trie) → rooft+ree
# rooftree (Suffix Trie) → rooft+ree
#
# legend (Prefix Trie) → leg+end
# legend (Suffix Trie) → leg+end
#
# sorrow (Prefix Trie) → sorr+ow
# sorrow (Suffix Trie) → s+orrow
#
# teeth (Prefix Trie) → teet+h
# teeth (Suffix Trie) → te+eth
#
# mouth (Prefix Trie) → mouth+
# mouth (Suffix Trie) → +mouth
#
# pebbles (Prefix Trie) → pe+bbles
# pebbles (Suffix Trie) → pe+bbles
#
# wife (Prefix Trie) → wi+fe
# wife (Suffix Trie) → +wife
#
# fishmongers (Prefix Trie) → fish+mongers
# fishmongers (Suffix Trie) → fishmo+ngers
#
# trolley (Prefix Trie) → troll+ey
# trolley (Suffix Trie) → tr+olley
#
# car (Prefix Trie) → car+
# car (Suffix Trie) → +car
#
# stomach (Prefix Trie) → stomac+h
# stomach (Suffix Trie) → stom+ach
#
# note (Prefix Trie) → note+
# note (Suffix Trie) → +note
#
# vandals (Prefix Trie) → vandal+s
# vandals (Suffix Trie) → v+andals
#
# loot (Prefix Trie) → loo+t
# loot (Suffix Trie) → l+oot
#
# cycle (Prefix Trie) → cycl+e
# cycle (Suffix Trie) → cy+cle
#
# disaster (Prefix Trie) → disas+ter
# disaster (Suffix Trie) → dis+aster
#
# moment (Prefix Trie) → moment+
# moment (Suffix Trie) → mo+ment
#
# belonging (Prefix Trie) → bel+onging
# belonging (Suffix Trie) → bel+onging
#
# generation (Prefix Trie) → generat+ion
# generation (Suffix Trie) → g+eneration
#
# sort (Prefix Trie) → sort+
# sort (Suffix Trie) → s+ort
#
# doubt (Prefix Trie) → doubt+
# doubt (Suffix Trie) → dou+bt
#
# preceding (Prefix Trie) → preced+ing
# preceding (Suffix Trie) → prec+eding
#
# pap (Prefix Trie) → pap+
# pap (Suffix Trie) → p+ap
#
# gage (Prefix Trie) → gag+e
# gage (Suffix Trie) → +gage
#
# rods (Prefix Trie) → rod+s
# rods (Suffix Trie) → r+ods
#
# pizza (Prefix Trie) → pizz+a
# pizza (Suffix Trie) → pi+zza
#
# pinball (Prefix Trie) → pin+ball
# pinball (Suffix Trie) → pi+nball
#
# taverns (Prefix Trie) → ta+verns
# taverns (Suffix Trie) → tav+erns
#
# case (Prefix Trie) → case+
# case (Suffix Trie) → +case
#
# wisenheimer (Prefix Trie) → wis+enheimer
# wisenheimer (Suffix Trie) → wisenhe+imer
#
# joss (Prefix Trie) → jo+ss
# joss (Suffix Trie) → j+oss
#
# couple (Prefix Trie) → couple+
# couple (Suffix Trie) → cou+ple
#
# years (Prefix Trie) → year+s
# years (Suffix Trie) → y+ears
#
# apartment (Prefix Trie) → apart+ment
# apartment (Suffix Trie) → a+partment
#
# staircase (Prefix Trie) → stair+case
# staircase (Suffix Trie) → stair+case
#
# type (Prefix Trie) → type+
# type (Suffix Trie) → +type
#
# niche (Prefix Trie) → nic+he
# niche (Suffix Trie) → n+iche
#
# coffin (Prefix Trie) → coff+in
# coffin (Suffix Trie) → coff+in
#
# turn (Prefix Trie) → turn+
# turn (Suffix Trie) → +turn
#
# stone (Prefix Trie) → stone+
# stone (Suffix Trie) → +stone
#
# merit (Prefix Trie) → mer+it
# merit (Suffix Trie) → me+rit
#
# wife (Prefix Trie) → wi+fe
# wife (Suffix Trie) → +wife
#
# flowers (Prefix Trie) → flower+s
# flowers (Suffix Trie) → f+lowers
#
# pennies (Prefix Trie) → penn+ies
# pennies (Suffix Trie) → pe+nnies
#
# lap (Prefix Trie) → lap+
# lap (Suffix Trie) → l+ap
#
# while (Prefix Trie) → whi+le
# while (Suffix Trie) → wh+ile
#
# money (Prefix Trie) → mone+y
# money (Suffix Trie) → m+oney
#
# suspicions (Prefix Trie) → susp+icions
# suspicions (Suffix Trie) → susp+icions
#
# process (Prefix Trie) → process+
# process (Suffix Trie) → pro+cess
#
# elimination (Prefix Trie) → eli+mination
# elimination (Suffix Trie) → el+imination
#
# boy (Prefix Trie) → boy+
# boy (Suffix Trie) → +boy
#
# hat (Prefix Trie) → hat+
# hat (Suffix Trie) → h+at
#
# cartons (Prefix Trie) → carto+ns
# cartons (Suffix Trie) → car+tons
#
# people (Prefix Trie) → peo+ple
# people (Suffix Trie) → peo+ple
#
# activities (Prefix Trie) → activit+ies
# activities (Suffix Trie) → ac+tivities
#
# character (Prefix Trie) → character+
# character (Suffix Trie) → chara+cter
#
# example (Prefix Trie) → exam+ple
# example (Suffix Trie) → ex+ample
#
# practice (Prefix Trie) → practic+e
# practice (Suffix Trie) → prac+tice
#
# dogs (Prefix Trie) → dog+s
# dogs (Suffix Trie) → d+ogs
#
# winter (Prefix Trie) → winter+
# winter (Suffix Trie) → w+inter
#
# salt (Prefix Trie) → salt+
# salt (Suffix Trie) → s+alt
#
# pavement (Prefix Trie) → pav+ement
# pavement (Suffix Trie) → p+avement
#
# feet (Prefix Trie) → fee+t
# feet (Suffix Trie) → f+eet
#
# energy (Prefix Trie) → energ+y
# energy (Suffix Trie) → en+ergy
#
# dawn (Prefix Trie) → da+wn
# dawn (Suffix Trie) → d+awn
#
# garbage (Prefix Trie) → gar+bage
# garbage (Suffix Trie) → gar+bage
#
# collector (Prefix Trie) → collect+or
# collector (Suffix Trie) → col+lector
#
# pails (Prefix Trie) → pai+ls
# pails (Suffix Trie) → p+ails
#
# areaways (Prefix Trie) → area+ways
# areaways (Suffix Trie) → ar+eaways
#
# lions (Prefix Trie) → lion+s
# lions (Suffix Trie) → +lions
#
# cigar (Prefix Trie) → cigar+
# cigar (Suffix Trie) → ci+gar
#
# butts (Prefix Trie) → butt+s
# butts (Suffix Trie) → bu+tts
#
# paws (Prefix Trie) → paw+s
# paws (Suffix Trie) → p+aws
#
# evenings (Prefix Trie) → even+ings
# evenings (Suffix Trie) → ev+enings
#
# restaurants (Prefix Trie) → restaura+nts
# restaurants (Suffix Trie) → restau+rants
#
# hats (Prefix Trie) → hat+s
# hats (Suffix Trie) → h+ats
#
# phrase (Prefix Trie) → phrase+
# phrase (Suffix Trie) → ph+rase
#
# timber (Prefix Trie) → timber+
# timber (Suffix Trie) → t+imber
#
# toad (Prefix Trie) → toad+
# toad (Suffix Trie) → t+oad
#
# animals (Prefix Trie) → anima+ls
# animals (Suffix Trie) → an+imals
#
# humans (Prefix Trie) → human+s
# humans (Suffix Trie) → hum+ans
#
# course (Prefix Trie) → cour+se
# course (Suffix Trie) → +course
#
# morning (Prefix Trie) → mor+ning
# morning (Suffix Trie) → mo+rning
#
# pennies (Prefix Trie) → penn+ies
# pennies (Suffix Trie) → pe+nnies
#
# idol (Prefix Trie) → idol+
# idol (Suffix Trie) → id+ol
#
# cigarette (Prefix Trie) → cigar+ette
# cigarette (Suffix Trie) → cig+arette
#
# lap (Prefix Trie) → lap+
# lap (Suffix Trie) → l+ap
#
# wife (Prefix Trie) → wi+fe
# wife (Suffix Trie) → +wife
#
# divinity (Prefix Trie) → divinit+y
# divinity (Suffix Trie) → div+inity
#
# time (Prefix Trie) → time+
# time (Suffix Trie) → +time
#
# person (Prefix Trie) → person+
# person (Suffix Trie) → pe+rson
#
# years (Prefix Trie) → year+s
# years (Suffix Trie) → y+ears
#
# face (Prefix Trie) → face+
# face (Suffix Trie) → +face
#
# color (Prefix Trie) → color+
# color (Suffix Trie) → +color
#
# tallow (Prefix Trie) → tall+ow
# tallow (Suffix Trie) → t+allow
#
# wrinkles (Prefix Trie) → wri+nkles
# wrinkles (Suffix Trie) → w+rinkles
#
# chicken (Prefix Trie) → chick+en
# chicken (Suffix Trie) → chic+ken
#
# wire (Prefix Trie) → wir+e
# wire (Suffix Trie) → w+ire
#
# sort (Prefix Trie) → sort+
# sort (Suffix Trie) → s+ort
#
# nemesis (Prefix Trie) → ne+mesis
# nemesis (Suffix Trie) → ne+mesis
#
# footsteps (Prefix Trie) → footst+eps
# footsteps (Suffix Trie) → footst+eps
#
# voice (Prefix Trie) → voi+ce
# voice (Suffix Trie) → v+oice
#
# ape (Prefix Trie) → ape+
# ape (Suffix Trie) → +ape
#
# specter (Prefix Trie) → spect+er
# specter (Suffix Trie) → spe+cter
#
# eyes (Prefix Trie) → eye+s
# eyes (Suffix Trie) → e+yes
#
# stare (Prefix Trie) → star+e
# stare (Suffix Trie) → st+are
#
# safe (Prefix Trie) → safe+
# safe (Suffix Trie) → s+afe
#
# band (Prefix Trie) → band+
# band (Suffix Trie) → +band
#
# grocery (Prefix Trie) → grocer+y
# grocery (Suffix Trie) → gro+cery
#
# youth (Prefix Trie) → you+th
# youth (Suffix Trie) → y+outh
#
# effect (Prefix Trie) → effect+
# effect (Suffix Trie) → e+ffect
#
# customers (Prefix Trie) → custom+ers
# customers (Suffix Trie) → cust+omers
#
# threat (Prefix Trie) → threa+t
# threat (Suffix Trie) → th+reat
#
# incubi (Prefix Trie) → incub+i
# incubi (Suffix Trie) → incu+bi
#
# part (Prefix Trie) → part+
# part (Suffix Trie) → +part
#
# disintegration (Prefix Trie) → disinte+gration
# disintegration (Suffix Trie) → disinte+gration
#
# way (Prefix Trie) → wa+y
# way (Suffix Trie) → +way
#
# beggary (Prefix Trie) → beggar+y
# beggary (Suffix Trie) → begg+ary
#
# job (Prefix Trie) → job+
# job (Suffix Trie) → j+ob
#
# office (Prefix Trie) → office+
# office (Suffix Trie) → of+fice
#
# boy (Prefix Trie) → boy+
# boy (Suffix Trie) → +boy
#
# television (Prefix Trie) → tele+vision
# television (Suffix Trie) → tel+evision
#
# producer (Prefix Trie) → produc+er
# producer (Suffix Trie) → pro+ducer
#
# hubris (Prefix Trie) → hub+ris
# hubris (Suffix Trie) → hu+bris
#
# deficiency (Prefix Trie) → deficienc+y
# deficiency (Suffix Trie) → de+ficiency
#
# taste (Prefix Trie) → tas+te
# taste (Suffix Trie) → t+aste
#
# sadism (Prefix Trie) → sadis+m
# sadism (Suffix Trie) → sa+dism
#
# top (Prefix Trie) → top+
# top (Suffix Trie) → +top
#
# programs (Prefix Trie) → program+s
# programs (Suffix Trie) → pro+grams
#
# depths (Prefix Trie) → dept+hs
# depths (Suffix Trie) → dep+ths
#
# bathos (Prefix Trie) → bath+os
# bathos (Suffix Trie) → b+athos
#
# networks (Prefix Trie) → net+works
# networks (Suffix Trie) → ne+tworks
#
# boss (Prefix Trie) → boss+
# boss (Suffix Trie) → b+oss
#
# elevator (Prefix Trie) → elevat+or
# elevator (Suffix Trie) → elev+ator
#
# dozen (Prefix Trie) → do+zen
# dozen (Suffix Trie) → do+zen
#
# cigars (Prefix Trie) → cigar+s
# cigars (Suffix Trie) → ci+gars
#
# man (Prefix Trie) → man+
# man (Suffix Trie) → +man
#
# guy (Prefix Trie) → gu+y
# guy (Suffix Trie) → g+uy
#
# operator (Prefix Trie) → operat+or
# operator (Suffix Trie) → op+erator
#
# shoes (Prefix Trie) → shoe+s
# shoes (Suffix Trie) → s+hoes
#
# rice (Prefix Trie) → ric+e
# rice (Suffix Trie) → +rice
#
# kind (Prefix Trie) → kind+
# kind (Suffix Trie) → k+ind
#
# nemesis (Prefix Trie) → ne+mesis
# nemesis (Suffix Trie) → ne+mesis
#
# footsteps (Prefix Trie) → footst+eps
# footsteps (Suffix Trie) → footst+eps
#
# horoscope (Prefix Trie) → hor+oscope
# horoscope (Suffix Trie) → ho+roscope
#
# autumn (Prefix Trie) → aut+umn
# autumn (Suffix Trie) → aut+umn
#
# reverse (Prefix Trie) → revers+e
# reverse (Suffix Trie) → re+verse
#
# inventory (Prefix Trie) → inventor+y
# inventory (Suffix Trie) → inven+tory
#
# people (Prefix Trie) → peo+ple
# people (Suffix Trie) → peo+ple
#
# street (Prefix Trie) → street+
# street (Suffix Trie) → str+eet
#
# sprue (Prefix Trie) → spru+e
# sprue (Suffix Trie) → sp+rue
#
# yaws (Prefix Trie) → yaw+s
# yaws (Suffix Trie) → y+aws
#
# boil (Prefix Trie) → boil+
# boil (Suffix Trie) → b+oil
#
# wilt (Prefix Trie) → wil+t
# wilt (Suffix Trie) → w+ilt
#
# liver (Prefix Trie) → liver+
# liver (Suffix Trie) → l+iver
#
# fluke (Prefix Trie) → flu+ke
# fluke (Suffix Trie) → fl+uke
#
# bilharziasis (Prefix Trie) → bil+harziasis
# bilharziasis (Suffix Trie) → bilharz+iasis
#
# host (Prefix Trie) → host+
# host (Suffix Trie) → h+ost
#
# complications (Prefix Trie) → complic+ations
# complications (Suffix Trie) → co+mplications
#
# hex (Prefix Trie) → he+x
# hex (Suffix Trie) → h+ex
#
# advice (Prefix Trie) → advi+ce
# advice (Suffix Trie) → ad+vice
#
# vocation (Prefix Trie) → voca+tion
# vocation (Suffix Trie) → +vocation
#
# time (Prefix Trie) → time+
# time (Suffix Trie) → +time
#
# headache (Prefix Trie) → head+ache
# headache (Suffix Trie) → head+ache
#
# doors (Prefix Trie) → door+s
# doors (Suffix Trie) → +doors
#
# train (Prefix Trie) → train+
# train (Suffix Trie) → +train
#
# seat (Prefix Trie) → seat+
# seat (Suffix Trie) → s+eat
#
# aisle (Prefix Trie) → ai+sle
# aisle (Suffix Trie) → ais+le
#
# aviary (Prefix Trie) → avia+ry
# aviary (Suffix Trie) → av+iary
#
# head (Prefix Trie) → head+
# head (Suffix Trie) → +head
#
# song (Prefix Trie) → song+
# song (Suffix Trie) → s+ong
#
# doll (Prefix Trie) → doll+
# doll (Suffix Trie) → d+oll
#
# mistake (Prefix Trie) → mistak+e
# mistake (Suffix Trie) → mis+take
#
# bang (Prefix Trie) → bang+
# bang (Suffix Trie) → b+ang
#
# cheekbones (Prefix Trie) → cheek+bones
# cheekbones (Suffix Trie) → cheek+bones
#
# strain (Prefix Trie) → strai+n
# strain (Suffix Trie) → s+train
#
# lineage (Prefix Trie) → line+age
# lineage (Suffix Trie) → lin+eage
#
# mouth (Prefix Trie) → mouth+
# mouth (Suffix Trie) → +mouth
#
# fault (Prefix Trie) → fau+lt
# fault (Suffix Trie) → f+ault
#
# phrase (Prefix Trie) → phrase+
# phrase (Suffix Trie) → ph+rase
#
# lip (Prefix Trie) → li+p
# lip (Suffix Trie) → +lip
#
# trifle (Prefix Trie) → tri+fle
# trifle (Suffix Trie) → tri+fle
#
# gauge (Prefix Trie) → gau+ge
# gauge (Suffix Trie) → ga+uge
#
# glance (Prefix Trie) → glan+ce
# glance (Suffix Trie) → g+lance
#
# figure (Prefix Trie) → figur+e
# figure (Suffix Trie) → fig+ure
#
# boucle (Prefix Trie) → bou+cle
# boucle (Suffix Trie) → bou+cle
#
# dress (Prefix Trie) → dress+
# dress (Suffix Trie) → +dress

# %% [markdown]
# Prefix Trie → insert uses characters left-to-right.
#
# Suffix Trie → insert uses characters right-to-left (reversed word).

# %% [markdown]
# ## Final Report / Analysis
#
# Prefix Trie:
#
# - Captures common roots/prefixes.
#
# - Works well when stem is at the start of word (English verbs, plurals like go → goes, going).
#
# Suffix Trie:
#
# - Captures common endings/suffixes.
#
# - Works better for English since most morphology is suffix-based (-s, -es, -ing, -ed).
#
# - Example: cats, dogs, bikes → suffix "s" is easily detected.
#
# Conclusion:
#
# - Both tries can split words into stem + suffix.
#
# - But Suffix Trie performs better in stemming because English mainly modifies words at the end (plural, tense, derivation).
#
# - Prefix Trie may mistakenly split too early in some cases (like players = play+ers instead of player+s).
#
# - Therefore, for English stemming → Suffix Trie is more effective.
